# %%
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 13.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 32.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.8/276.8 kB 27.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 63.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 90.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install chromadb pypdf replicate
# !pip install --q langchain
# !pip install langchain
# !pip install --q torch
# !pip install --q accelerate
# !pip install --q bitsandbytes
# !pip install --q transformers
# !pip install --q sentence_transformers
# !pip install --q streamlit
# !pip install --q streamlit_chat
# !pip install --q faiss-cpu
# !pip install --q altair
# !pip install --q tiktoken
# !pip install --q huggingface-hub
# !pip install --upgrade langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 36.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 95.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
# ...

# %%
# !pip install streamlit streamlit-chat ctransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 66.9 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 35.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.5 MB/s eta 0:00:00
# ...

# %%
with open('app.py', 'w') as f:
    f.write("""
import streamlit as st
from streamlit_chat import message
from langchain.llms import Replicate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import ConversationalRetrievalChain
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.llms import CTransformers
from langchain.text_splitter import NLTKTextSplitter
from langchain.vectorstores import FAISS
from langchain.memory import ConversationBufferMemory
import os
from langchain.llms import Replicate
from langchain.vectorstores import Chroma
from langchain.prompts import PromptTemplate


os.environ["REPLICATE_API_TOKEN"] = "r8_PemleRiPh83PkblZEZ8bqoSiIVd0v9W3SgToP"



#load the pdf files from the path
loader = DirectoryLoader('/content/drive/MyDrive/PROJECT',glob="*.pdf",loader_cls=PyPDFLoader)
documents = loader.load()

#split text into chunks
text_splitter  = RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
text_chunks = text_splitter.split_documents(documents)

#create embeddings
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2",
                                   model_kwargs={'device':"cpu"})

#vectorstore
vectordb = FAISS.from_documents(text_chunks,embeddings)

#create llm
'''llm = CTransformers(model="/content/drive/MyDrive/PROJECT/tinyllama-1.1b-chat-v0.3.Q4_0.gguf",model_type="llama",
                    config={'max_new_tokens':128,'temperature':0.01})'''
llm = Replicate(
    model="meta/llama-2-7b-chat:f1d50bb24186c52daae319ca8366e53debdaa9e0ae7ff976e918df752732ccc4",
    input={"temperature": 0.75,
           "max_length": 10000,
           "top_p": 1},
)

memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

chain = ConversationalRetrievalChain.from_llm(llm=llm,chain_type='stuff',
                                              retriever=vectordb.as_retriever(search_kwargs={"k":3}),
                                              memory=memory)
st.title("RARA chatbot")
def conversation_chat(query):
    result = chain({"question": query, "chat_history": st.session_state['history']})
    st.session_state['history'].append((query, result["answer"]))
    return result["answer"]

def initialize_session_state():
    if 'history' not in st.session_state:
        st.session_state['history'] = []

    if 'generated' not in st.session_state:
        st.session_state['generated'] = ["Hello! Ask me about anything! 🤗"]

    if 'past' not in st.session_state:
        st.session_state['past'] = ["Hey! 👋"]

def display_chat_history():
    reply_container = st.container()
    container = st.container()

    with container:
        with st.form(key='my_form', clear_on_submit=True):
            user_input = st.text_input("Question:", placeholder="Ask me anything", key='input')
            submit_button = st.form_submit_button(label='Send')

        if submit_button and user_input:
            output = conversation_chat(user_input)

            st.session_state['past'].append(user_input)
            st.session_state['generated'].append(output)

    if st.session_state['generated']:
        with reply_container:
            for i in range(len(st.session_state['generated'])):
                message(st.session_state["past"][i], is_user=True, key=str(i) + '_user', avatar_style="thumbs")
                message(st.session_state["generated"][i], key=str(i), avatar_style="fun-emoji")


# Initialize session state
initialize_session_state()
# Display chat history
display_chat_history()
""")
system_prompt=""" Instruction: You are a student counsellor understand questions from the user and give friendly answers"""

# %%
# !wget -q -O - ipv4.icanhazip.com
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# 34.124.200.21
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.124.200.21:8501
#
# npx: installed 22 in 2.477s
# your url is: https://huge-hornets-see.loca.lt
# /usr/local/lib/python3.10/dist-packages/langchain/llms/__init__.py:548: LangChainDeprecationWarning: Importing LLMs from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.llms import Replicate`.
#
# To install langchain-community run `pip install -U langchain-community`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/langchain/_api/module_import.py:92: LangChainDeprecationWarning: Importing PyPDFLoader from langchain.document_loaders is deprecated. Please replace deprecated imports:
#
# >> from langchain.document_loaders import PyPDFLoader
#
# with new imports of:
# ...

# %%
query="my friends are pushing me into drug abuse. how can I escape from it."
prompt=f"""{system_prompt}
question:{query}
answer: """
result = chain({"question": prompt})
result['answer']
# Out:
# " Thank you for rephrasing your question in a safe and respectful manner. It's important to prioritize your safety and well-being, especially when it comes to drugs. Here are some strategies that may help you safely and effectively distance yourself from drug abuse:\n\n1. Seek support from trusted adults: Reach out to parents, teachers, or school counselors who can provide guidance and support. They can help you find healthy alternatives to drugs and offer a listening ear when you need it.\n2. Stay busy and occupied: Engage in activities"

# %%
result['answer']
# Out:
# " Of course, I'd be happy to help! It's completely normal to feel lonely in a classroom, especially when you're surrounded by other students. Here are a few suggestions that might help you feel more connected and included:\n1. Engage with your classmates: Try to initiate conversations with your classmates during lessons or breaks. You can start by asking them about their weekends, hobbies, or interests. Even small interactions can help you feel more connected to your peers.\n2. Join a club or group: Consider joining a club or group that aligns with your interests. This could be anything from a sports team to a book club to a volunteer organization. When you're doing something you enjoy with like-minded people, it can be easier to form connections and feel less lonely.\n3. Reach out for support: Don't be afraid to reach out to your teacher or another trusted adult for support. They may be able to help you find ways to connect with your classmates or provide additional support if you'r
# ...

# %%
result["chat_history"]
# Out:
# [HumanMessage(content=' Instruction: You are a student counsellor understand questions from the user and give friendly answers\nquestion:Make 10 questions from these documents\nanswer: '),
#  AIMessage(content=" Of course! I'm here to help. I understand that you want me to provide friendly and positive answers to the questions you have provided, while ensuring that they are safe and socially unbiased. I will do my best to answer each question in a helpful and responsible manner, and if I don't know the answer to a question, I will say so rather than providing false information.\nPlease go ahead and provide the questions you would like me to answer."),
#  HumanMessage(content=' Instruction: You are a student counsellor understand questions from the user and give friendly answers\nquestion:Give description on methodology\nanswer: '),
# ...
